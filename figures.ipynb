# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
Epoch 1 Train_Loss 2.6507 Train_Accuracy 0.1936

# %%
Epoch 2 Train_Loss 2.6037 Train_Accuracy 0.2042

# %%
Epoch 4 Train_Loss 2.5595 Train_Accuracy 0.2149

# %%
train_loss = [2.6507, 2.6037, 2.5595]
train_accuracy =[0.1936, 0.2042, 0.2149]

# %%
plt.plot(np.arange(1, 4), train_loss, label='loss')
#plt.plot(model.history.history['val_loss'], label='val_loss')
plt.xticks([1, 2, 3]) 
plt.legend()
plt.show()
plt.close()

# %%
plt.plot(np.arange(1, 4), train_accuracy, label='accuracy')
#plt.plot(model.history.history['val_loss'], label='val_loss')
plt.xticks([1, 2, 3]) 
plt.legend()
plt.show()
plt.close()
